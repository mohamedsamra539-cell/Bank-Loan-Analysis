# %% [markdown]
# # Bank Loan Analysis
#
# ## Project Overview
#
# The goal of this project is to analyze bank loan data to understand customer behavior, loan performance, and factors affecting loan status.
#
# The project workflow includes:
# - import libraries
# - Loading data
# - Data Understanding
# - Data Cleaning
# - SQL Analysis
# - Power BI Dashboard
# - Business Insights

# %% [markdown]
# ## import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %% [markdown]
# ## loading data

# %%
Bank = pd.read_csv(r"C:\My Project\Bank\Bank_loan.csv")

# %% [markdown]
# ## understandin data

# %%
Bank.head()
# Out:
#         id address_state application_type emp_length              emp_title  \
# 0  1077430            GA       INDIVIDUAL   < 1 year                  Ryder
# 1  1072053            CA       INDIVIDUAL    9 years         MKC Accounting
# 2  1069243            CA       INDIVIDUAL    4 years  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL   < 1 year    barnes distribution
# 4  1068350            IL       INDIVIDUAL  10+ years          J&J Steel Inc
#
#   grade home_ownership  issue_date last_credit_pull_date last_payment_date  \
# 0     C           RENT  11-02-2021            13-09-2021        13-04-2021
# 1     E           RENT  01-01-2021            14-12-2021        15-01-2021
# 2     C           RENT  05-01-2021            12-12-2021        09-01-2021
# 3     B       MORTGAGE  25-02-2021            12-12-2021        12-03-2021
# 4     A       MORTGAGE  01-01-2021            14-12-2021        15-01-2021
#
# ...

# %%
Bank.columns
# Out:
# Index(['id', 'address_state', 'application_type', 'emp_length', 'emp_title',
#        'grade', 'home_ownership', 'issue_date', 'last_credit_pull_date',
#        'last_payment_date', 'loan_status', 'next_payment_date', 'member_id',
#        'purpose', 'sub_grade', 'term', 'verification_status', 'annual_income',
#        'dti', 'installment', 'int_rate', 'loan_amount', 'total_acc',
#        'total_payment'],
#       dtype='object')

# %%
Bank.shape
# Out:
# (38576, 24)

# %%
Bank.isnull().sum()
# Out:
# id                          0
# address_state               0
# application_type            0
# emp_length                  0
# emp_title                1438
# grade                       0
# home_ownership              0
# issue_date                  0
# last_credit_pull_date       0
# last_payment_date           0
# loan_status                 0
# next_payment_date           0
# member_id                   0
# purpose                     0
# sub_grade                   0
# term                        0
# verification_status         0
# annual_income               0
# dti                         0
# installment                 0
# int_rate                    0
# loan_amount                 0
# total_acc                   0
# total_payment               0
# dtype: int64

# %% [markdown]
# we have 1438 null values in emp_title column

# %%
Bank.duplicated().sum()
# Out:
# np.int64(0)

# %%
Bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38576 entries, 0 to 38575
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     38576 non-null  int64
#  1   address_state          38576 non-null  object
#  2   application_type       38576 non-null  object
#  3   emp_length             38576 non-null  object
#  4   emp_title              37138 non-null  object
#  5   grade                  38576 non-null  object
#  6   home_ownership         38576 non-null  object
#  7   issue_date             38576 non-null  object
#  8   last_credit_pull_date  38576 non-null  object
#  9   last_payment_date      38576 non-null  object
#  10  loan_status            38576 non-null  object
#  11  next_payment_date      38576 non-null  object
#  12  member_id              38576 non-null  int64
#  13  purpose                38576 non-null  object
# ...

# %% [markdown]
# The date columns have the wrong data type.

# %%
Bank.describe()
# Out:
#                  id     member_id  annual_income           dti   installment  \
# count  3.857600e+04  3.857600e+04   3.857600e+04  38576.000000  38576.000000
# mean   6.810371e+05  8.476515e+05   6.964454e+04      0.133274    326.862965
# std    2.113246e+05  2.668105e+05   6.429368e+04      0.066662    209.092000
# min    5.473400e+04  7.069900e+04   4.000000e+03      0.000000     15.690000
# 25%    5.135170e+05  6.629788e+05   4.150000e+04      0.082100    168.450000
# 50%    6.627280e+05  8.473565e+05   6.000000e+04      0.134200    283.045000
# 75%    8.365060e+05  1.045652e+06   8.320050e+04      0.185900    434.442500
# max    1.077501e+06  1.314167e+06   6.000000e+06      0.299900   1305.190000
#
#            int_rate   loan_amount     total_acc  total_payment
# count  38576.000000  38576.000000  38576.000000   38576.000000
# mean       0.120488  11296.066855     22.132544   12263.348533
# std        0.037164   7460.746022     11.392282    9051.104777
# ...

# %% [markdown]
# Outlier Handling
#
# After examining the numerical columns (`annual_income`, `loan_amount`, `interest_rate`, `installment`, `debt_to_income_ratio`, `total_payment`, and `total_accounts`) using descriptive statistics and boxplots, no outliers were removed.
#
# This decision was made because the detected extreme values appear to represent **valid customer records rather than data entry errors**. In banking datasets, customers can naturally have very high incomes, large loan amounts, or high total payments. Removing these observations could eliminate important business cases and introduce bias into the analysis.
#
# Only invalid or impossible values (e.g., negative income, negative loan amount, or unrealistic interest rates) would be considered for removal. Since no such values were identified, all records were retained for the analysis.

# %%
Bank["grade"].value_counts()
# Out:
# grade
# B    11674
# A     9689
# C     7904
# D     5182
# E     2786
# F     1028
# G      313
# Name: count, dtype: int64

# %%
Bank["loan_status"].value_counts()
# Out:
# loan_status
# Fully Paid     32145
# Charged Off     5333
# Current         1098
# Name: count, dtype: int64

# %%
Bank["home_ownership"].value_counts()
# Out:
# home_ownership
# RENT        18439
# MORTGAGE    17198
# OWN          2838
# OTHER          98
# NONE            3
# Name: count, dtype: int64

# %%
Bank[Bank["home_ownership"] == "NONE"]
# Out:
#            id address_state application_type emp_length emp_title grade  \
# 7744   231321            VA       INDIVIDUAL    5 years       ups     A
# 31666  121535            MA       INDIVIDUAL   < 1 year       NaN     B
# 31667  121568            CA       INDIVIDUAL   < 1 year       NaN     B
#
#       home_ownership  issue_date last_credit_pull_date last_payment_date  ...  \
# 7744            NONE  08-01-2021            11-01-2021        11-02-2021  ...
# 31666           NONE  07-08-2021            07-08-2021        10-09-2021  ...
# 31667           NONE  07-08-2021            07-08-2021        10-09-2021  ...
#
#       sub_grade        term  verification_status annual_income     dti  \
# 7744         A3   36 months         Not Verified       22200.0  0.0524
# 31666        B1   36 months         Not Verified      120000.0  0.1500
# 31667        B4   36 months         Not Verified      100000.0  0.1500
#
#       installment int_rate  loan_amount  total_acc  total_payment
# ...

# %%
Bank["home_ownership"]=Bank["home_ownership".replace("NONE","OTHER")]

# %%
Bank["home_ownership"].value_counts()
# Out:
# home_ownership
# RENT        18439
# MORTGAGE    17198
# OWN          2838
# OTHER          98
# NONE            3
# Name: count, dtype: int64

# %%
Bank["purpose"].value_counts()
# Out:
# purpose
# Debt consolidation    18214
# credit card            4998
# other                  3824
# home improvement       2876
# major purchase         2110
# small business         1776
# car                    1497
# wedding                 928
# medical                 667
# moving                  559
# house                   366
# vacation                352
# educational             315
# renewable_energy         94
# Name: count, dtype: int64

# %% [markdown]
# Debt consolidation is the most common reason for loan applications, indicating that many customers use loans to combine existing debts into a single payment.

# %% [markdown]
# ## cleaning data

# %%
Bank["emp_title"]=Bank['emp_title'].fillna("Unknown")

# %%
date_cols = [
    "issue_date",
    "last_credit_pull_date",
    "last_payment_date",
    "next_payment_date"
]

for col in date_cols:
    Bank[col] = pd.to_datetime(
        Bank[col],
        format="%d-%m-%Y",
        errors="coerce"
    )

# %%
Bank["emp_length"].value_counts()
# Out:
# emp_length
# 10+ years    8870
# < 1 year     4575
# 2 years      4382
# 3 years      4088
# 4 years      3428
# 5 years      3273
# 1 year       3229
# 6 years      2228
# 7 years      1772
# 8 years      1476
# 9 years      1255
# Name: count, dtype: int64

# %%
# Cleaning emp_length dynamically
Bank["emp_length"] = (
    pd.to_numeric(
        Bank["emp_length"].astype(str).str.extract(r"(\d+)", expand=False),
        errors="coerce",
    )
    .fillna(0)
    .astype(int)
)

# %%
Bank["emp_length"].value_counts()
# Out:
# emp_length
# 10    8870
# 1     7804
# 2     4382
# 3     4088
# 4     3428
# 5     3273
# 6     2228
# 7     1772
# 8     1476
# 9     1255
# Name: count, dtype: int64

# %%
Bank.rename(columns={"term": "loan_term_months"}, inplace=True)

# %%
Bank.sample()
# Out:
#             id address_state application_type  emp_length       emp_title  \
# 27948  1019133            CT       INDIVIDUAL          10  Winkle Bus Inc
#
#       grade home_ownership issue_date last_credit_pull_date last_payment_date  \
# 27948     C       MORTGAGE 2021-11-11            2021-06-15        2021-12-14
#
#        ... sub_grade loan_term_months  verification_status annual_income  \
# 27948  ...        C3        36 months         Not Verified      105000.0
#
#           dti installment int_rate  loan_amount  total_acc  total_payment
# 27948  0.0336      172.48   0.1465         5000         12           6209
#
# [1 rows x 24 columns]

# %%
Bank["loan_term_months"].value_counts()
# Out:
# loan_term_months
# 36 months    28237
# 60 months    10339
# Name: count, dtype: int64

# %%
Bank["loan_term_months"]=Bank["loan_term_months"].str.replace("months","").astype(int)

# %%
Bank["loan_term_months"].value_counts()
# Out:
# loan_term_months
# 36    28237
# 60    10339
# Name: count, dtype: int64

# %%
Bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38576 entries, 0 to 38575
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     38576 non-null  int64
#  1   address_state          38576 non-null  object
#  2   application_type       38576 non-null  object
#  3   emp_length             38576 non-null  int64
#  4   emp_title              38576 non-null  object
#  5   grade                  38576 non-null  object
#  6   home_ownership         38576 non-null  object
#  7   issue_date             38576 non-null  datetime64[ns]
#  8   last_credit_pull_date  38576 non-null  datetime64[ns]
#  9   last_payment_date      38576 non-null  datetime64[ns]
#  10  loan_status            38576 non-null  object
#  11  next_payment_date      38576 non-null  datetime64[ns]
#  12  member_id              38576 non-null  int64
#  13  purpose                38576 non-null  object
# ...

# %%
Bank_loan=Bank.to_csv("bank_loan_clean.csv", index=False)
